# %%
import pandas as pd
import numpy as np
import seaborn as sns                       
import matplotlib.pyplot as plt             
# %matplotlib inline     
sns.set(color_codes=True)

# %%
df = pd.read_csv(r"C:\Users\kenes\OneDrive\Рабочий стол\Логистика\kc_house_data.csv")

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
df.tail(5)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [5 rows x 21 columns]

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.shape
# Out:
# (21613, 21)

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 21)

# %%
df.count()
# Out:
# id               21613
# date             21613
# price            21613
# bedrooms         21613
# bathrooms        21613
# sqft_living      21613
# sqft_lot         21613
# floors           21613
# waterfront       21613
# view             21613
# condition        21613
# grade            21613
# sqft_above       21613
# sqft_basement    21613
# yr_built         21613
# yr_renovated     21613
# zipcode          21613
# lat              21613
# long             21613
# sqft_living15    21613
# sqft_lot15       21613
# dtype: int64

# %%
df = df.drop_duplicates()
df.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
df.count()
# Out:
# id               21613
# date             21613
# price            21613
# bedrooms         21613
# bathrooms        21613
# sqft_living      21613
# sqft_lot         21613
# floors           21613
# waterfront       21613
# view             21613
# condition        21613
# grade            21613
# sqft_above       21613
# sqft_basement    21613
# yr_built         21613
# yr_renovated     21613
# zipcode          21613
# lat              21613
# long             21613
# sqft_living15    21613
# sqft_lot15       21613
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df = df.dropna()   
df.count()
# Out:
# id               21613
# date             21613
# price            21613
# bedrooms         21613
# bathrooms        21613
# sqft_living      21613
# sqft_lot         21613
# floors           21613
# waterfront       21613
# view             21613
# condition        21613
# grade            21613
# sqft_above       21613
# sqft_basement    21613
# yr_built         21613
# yr_renovated     21613
# zipcode          21613
# lat              21613
# long             21613
# sqft_living15    21613
# sqft_lot15       21613
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
sns.boxplot(x=df['long'])
# Out:
# <Axes: xlabel='long'>

# %%
sns.boxplot(x=df['lat'])
# Out:
# <Axes: xlabel='lat'>

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# id               5.185851e+09
# price            3.230500e+05
# bedrooms         1.000000e+00
# bathrooms        7.500000e-01
# sqft_living      1.123000e+03
# sqft_lot         5.648000e+03
# floors           1.000000e+00
# waterfront       0.000000e+00
# view             0.000000e+00
# condition        1.000000e+00
# grade            1.000000e+00
# sqft_above       1.020000e+03
# sqft_basement    5.600000e+02
# yr_built         4.600000e+01
# yr_renovated     0.000000e+00
# zipcode          8.500000e+01
# lat              2.070000e-01
# long             2.030000e-01
# sqft_living15    8.700000e+02
# sqft_lot15       4.983000e+03
# dtype: float64
# C:\Users\kenes\AppData\Local\Temp\ipykernel_5752\4249959737.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1 = df.quantile(0.25)
# C:\Users\kenes\AppData\Local\Temp\ipykernel_5752\4249959737.py:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q3 = df.quantile(0.75)

# %%
df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df.shape
# Out:
# C:\Users\kenes\AppData\Local\Temp\ipykernel_5752\4147643536.py:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
# (14931, 21)

# %%
plt.figure(figsize=(10,5))
c= df.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
# C:\Users\kenes\AppData\Local\Temp\ipykernel_5752\2770685803.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c= df.corr()
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000  0.040283  0.004991   0.043166     0.045702 -0.051688
# price          0.040283  1.000000  0.239214   0.340767     0.514465 -0.085519
# bedrooms       0.004991  0.239214  1.000000   0.443816     0.614615  0.205092
# bathrooms      0.043166  0.340767  0.443816   1.000000     0.669337 -0.088711
# sqft_living    0.045702  0.514465  0.614615   0.669337     1.000000  0.164760
# sqft_lot      -0.051688 -0.085519  0.205092  -0.088711     0.164760  1.000000
# floors         0.031148  0.227441  0.128898   0.524475     0.317437 -0.416436
# waterfront          NaN       NaN       NaN        NaN          NaN       NaN
# view                NaN       NaN       NaN        NaN          NaN       NaN
# condition     -0.035743  0.084215  0.029109  -0.157639    -0.068415  0.151206
# grade          0.057318  0.527261  0.289933   0.584361     0.622565 -0.032188
# sqft_above     0.052968  0.408152  0.485829   0.592870     0.831448  0.114661
# sqft_basement -0.010668  0.200186  0.242182   0.155143     0.324253  0.091440
# yr_built       0.039624 -0.012176  0.159318   0.604099     0.351198 -0.106939
# yr_renovated        NaN       NaN       NaN        NaN          NaN       NaN
# zipcode       -0.034112 -0.008025 -0.189590  -0.250526    -0.239981 -0.257420
# lat           -0.007152  0.490997 -0.082263  -0.055468    -0.027359 -0.142242
# long           0.073904  0.049406  0.191199   0.301019     0.314039  0.222175
# sqft_living15  0.054787  0.447504  0.413615   0.515211     0.727137  0.200412
# sqft_lot15    -0.053420 -0.095735  0.196653  -0.091677     0.150074  0.882197
#
#                  floors  waterfront  view  condition     grade  sqft_above  \
# id             0.031148         NaN   NaN  -0.035743  0.057318    0.052968
# price          0.227441         NaN   NaN   0.084215  0.527261    0.408152
# bedrooms       0.128898         NaN   NaN   0.029109  0.289933    0.485829
# bathrooms      0.524475         NaN   NaN  -0.157639  0.584361    0.592870
# sqft_living    0.317437         NaN   NaN  -0.068415  0.622565    0.831448
# sqft_lot      -0.416436         NaN   NaN   0.151206 -0.032188    0.114661
# floors         1.000000         NaN   NaN  -0.302576  0.472503    0.518531
# waterfront          NaN         NaN   NaN        NaN       NaN         NaN
# view                NaN         NaN   NaN        NaN       NaN         NaN
# condition     -0.302576         NaN   NaN   1.000000 -0.189171   -0.189246
# grade          0.472503         NaN   NaN  -0.189171  1.000000    0.637885
# sqft_above     0.518531         NaN   NaN  -0.189246  0.637885    1.000000
# sqft_basement -0.330550         NaN   NaN   0.203177 -0.002877   -0.255985
# yr_built       0.552402         NaN   NaN  -0.405011  0.509145    0.473741
# yr_renovated        NaN         NaN   NaN        NaN       NaN         NaN
# zipcode       -0.060073         NaN   NaN   0.001657 -0.214973   -0.308117
# lat            0.010908         NaN   NaN   0.016100  0.060172   -0.103869
# long           0.142078         NaN   NaN  -0.105117  0.238483    0.426250
# sqft_living15  0.254738         NaN   NaN  -0.131915  0.603934    0.710195
# sqft_lot15    -0.423910         NaN   NaN   0.153056 -0.023650    0.101779
#
#                sqft_basement  yr_built  yr_renovated   zipcode       lat  \
# id                 -0.010668  0.039624           NaN -0.034112 -0.007152
# price               0.200186 -0.012176           NaN -0.008025  0.490997
# bedrooms            0.242182  0.159318           NaN -0.189590 -0.082263
# bathrooms           0.155143  0.604099           NaN -0.250526 -0.055468
# sqft_living         0.324253  0.351198           NaN -0.239981 -0.027359
# sqft_lot            0.091440 -0.106939           NaN -0.257420 -0.142242
# floors             -0.330550  0.552402           NaN -0.060073  0.010908
# waterfront               NaN       NaN           NaN       NaN       NaN
# view                     NaN       NaN           NaN       NaN       NaN
# condition           0.203177 -0.405011           NaN  0.001657  0.016100
# grade              -0.002877  0.509145           NaN -0.214973  0.060172
# sqft_above         -0.255985  0.473741           NaN -0.308117 -0.103869
# sqft_basement       1.000000 -0.195550           NaN  0.107063  0.129247
# yr_built           -0.195550  1.000000           NaN -0.344105 -0.193258
# yr_renovated             NaN       NaN           NaN       NaN       NaN
# zipcode             0.107063 -0.344105           NaN  1.000000  0.301986
# lat                 0.129247 -0.193258           NaN  0.301986  1.000000
# long               -0.179344  0.436360           NaN -0.583432 -0.161876
# sqft_living15       0.055950  0.362947           NaN -0.331813 -0.034344
# sqft_lot15          0.087821 -0.086088           NaN -0.257451 -0.140255
#
#                    long  sqft_living15  sqft_lot15
# id             0.073904       0.054787   -0.053420
# price          0.049406       0.447504   -0.095735
# bedrooms       0.191199       0.413615    0.196653
# bathrooms      0.301019       0.515211   -0.091677
# sqft_living    0.314039       0.727137    0.150074
# sqft_lot       0.222175       0.200412    0.882197
# floors         0.142078       0.254738   -0.423910
# waterfront          NaN            NaN         NaN
# view                NaN            NaN         NaN
# condition     -0.105117      -0.131915    0.153056
# grade          0.238483       0.603934   -0.023650
# sqft_above     0.426250       0.710195    0.101779
# sqft_basement -0.179344       0.055950    0.087821
# yr_built       0.436360       0.362947   -0.086088
# yr_renovated        NaN            NaN         NaN
# zipcode       -0.583432      -0.331813   -0.257451
# lat           -0.161876      -0.034344   -0.140255
# long           1.000000       0.414155    0.220322
# sqft_living15  0.414155       1.000000    0.214983
# sqft_lot15     0.220322       0.214983    1.000000

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['long'], df['price'])
ax.set_xlabel('long')
ax.set_ylabel('price')
plt.show()
